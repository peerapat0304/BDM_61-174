4_0.jpg
# /kaggle/input/bdm-2021-face/612110165_2_0.jpg
# /kaggle/input/bdm-2021-face/622110240_2_0.jpg
# /kaggle/input/bdm-2021-face/612110159_1_0.jpg
# /kaggle/input/bdm-2021-face/622110172_2_0.jpg
# /kaggle/input/bdm-2021-face/622110206_2_0.jpg
# /kaggle/input/bdm-2021-face/612110174_2_0.jpg
# /kaggle/input/bdm-2021-face/622110209_2_1.jpg

# %%
import glob
filename = glob.glob("/kaggle/input/bdm-2021-face/*.*")
filename[0].split("_")
# Out:
# ['/kaggle/input/bdm-2021-face/622110140', '4', '0.jpg']

# %%
label = np.array([float(item.split("_")[-1].split(".")[0]) for item in filename])

# %% [markdown]
# #### !mkdir train

# %%
# !mkdir train
# Out:
# mkdir: cannot create directory ‘train’: File exists

# %%
# !mkdir train/male
# !mkdir train/female
# Out:
# mkdir: cannot create directory ‘train/male’: File exists
# mkdir: cannot create directory ‘train/female’: File exists

# %%
#!rm -rf train/female/*  #Delete Data

# %%
import shutil 
for i in range(len(label)):
    if label[i] == 0:
        shutil.copy(filename[i], '/kaggle/working/train/male/')
    else:
        shutil.copy(filename[i], '/kaggle/working/train/female/')

# %%
# !mkdir test
# !mkdir test/male
# !mkdir test/female
# Out:
# mkdir: cannot create directory ‘test’: File exists
# mkdir: cannot create directory ‘test/male’: File exists
# mkdir: cannot create directory ‘test/female’: File exists

# %%
import glob
filemale = glob.glob("./train/male/*.*")
filefemale = glob.glob("./train/female/*.*")

# %%
midx = np.random.randint(len(filemale), size = 4)
fidx = np.random.randint(len(filefemale), size = 2)

# %%
for i in fidx:
    shutil.move(filefemale[i],'./test/female/')
for i in midx:
    shutil.move(filemale[i],'./test/male/')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_generator = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        #rescale = 1.0/255.0,   # Intensity Normalized
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False,   # randomly flip images
        validation_split=0.2)

# %%
train_dir = './train'
batch_size = 66
img_height = 100 
img_width  = 100
train_generator = data_generator.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training') # set as training data

validation_generator = data_generator.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation') # set as validation data
# Out:
# Found 66 images belonging to 2 classes.
# Found 15 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'female': 0, 'male': 1}

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
# preparing the layers in the Convolutional Deep Neural Network
def create_model():
    tf.random.set_seed(0)
    tf.compat.v1.reset_default_graph() # Clear Model
    model = Sequential()
    model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', input_shape = train_generator.image_shape))
    model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation = 'relu'))
    model.add(Conv2D(filters = 8, kernel_size = (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Flatten())
    model.add(Dense(units = 32, activation = 'relu'))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 16, activation = 'relu'))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 8, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'sigmoid'))
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = create_model()
fitted_model = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // 66,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // 15,
    epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 6s 6s/step - loss: 5.9831 - accuracy: 0.5152 - val_loss: 1.8000 - val_accuracy: 0.8000
# Epoch 2/100
# 1/1 [==============================] - 5s 5s/step - loss: 5.0662 - accuracy: 0.5909 - val_loss: 0.8611 - val_accuracy: 0.7333
# Epoch 3/100
# 1/1 [==============================] - 5s 5s/step - loss: 2.4163 - accuracy: 0.6061 - val_loss: 1.3969 - val_accuracy: 0.4667
# Epoch 4/100
# 1/1 [==============================] - 5s 5s/step - loss: 2.5565 - accuracy: 0.5303 - val_loss: 2.5976 - val_accuracy: 0.8000
# Epoch 5/100
# 1/1 [==============================] - 5s 5s/step - loss: 2.3197 - accuracy: 0.7273 - val_loss: 2.0939 - val_accuracy: 0.8000
# Epoch 6/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.8654 - accuracy: 0.7273 - val_loss: 1.4793 - val_accuracy: 0.8000
# Epoch 7/100
# 1/1 [==============================] - 5s 5s/step - loss: 1
100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0880 - accuracy: 0.9697 - val_loss: 0.2463 - val_accuracy: 0.8000
# Epoch 74/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.8000
# Epoch 75/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.1010 - accuracy: 0.9848 - val_loss: 0.2910 - val_accuracy: 0.8000
# Epoch 76/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0362 - accuracy: 0.9697 - val_loss: 0.4335 - val_accuracy: 0.6667
# Epoch 77/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.0374 - accuracy: 1.0000 - val_loss: 0.2991 - val_accuracy: 0.7333
# Epoch 78/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.1494 - accuracy: 0.9242 - val_loss: 0.2773 - val_accuracy: 0.7333
# Epoch 79/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.1712 - accuracy: 0.9697 - val_loss: 0.2917 - val_accuracy: 0.7333
# Epoch 80/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0718 - accuracy: 0.9697 - val_loss: 0.3631 - val_accuracy: 0.8667
# Epoch 81/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.1299 - accuracy: 0.9394 - val_loss: 0.2118 - val_accuracy: 0.8667
# Epoch 82/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0936 - accuracy: 0.9697 - val_loss: 0.4660 - val_accuracy: 0.6000
# Epoch 83/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.3046 - val_accuracy: 0.7333
# Epoch 84/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0456 - accuracy: 0.9848 - val_loss: 0.3639 - val_accuracy: 0.6667
# Epoch 85/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.1151 - accuracy: 0.9394 - val_loss: 0.3149 - val_accuracy: 0.7333
# Epoch 86/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0856 - accuracy: 0.9545 - val_loss: 0.2599 - val_accuracy: 0.7333
# Epoch 87/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0434 - accuracy: 0.9848 - val_loss: 0.3207 - val_accuracy: 0.7333
# Epoch 88/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.8667
# Epoch 89/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.1022 - accuracy: 0.9848 - val_loss: 0.7490 - val_accuracy: 0.6667
# Epoch 90/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0350 - accuracy: 0.9848 - val_loss: 0.2007 - val_accuracy: 0.8667
# Epoch 91/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.0781 - accuracy: 0.9697 - val_loss: 0.2886 - val_accuracy: 0.8000
# Epoch 92/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0322 - accuracy: 0.9848 - val_loss: 0.3214 - val_accuracy: 0.7333
# Epoch 93/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0620 - accuracy: 0.9848 - val_loss: 0.4336 - val_accuracy: 0.7333
# Epoch 94/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.1041 - accuracy: 0.9394 - val_loss: 0.2860 - val_accuracy: 0.7333
# Epoch 95/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0639 - accuracy: 0.9848 - val_loss: 0.2285 - val_accuracy: 0.8000
# Epoch 96/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0754 - accuracy: 0.9697 - val_loss: 0.2955 - val_accuracy: 0.8667
# Epoch 97/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0490 - accuracy: 0.9848 - val_loss: 0.2265 - val_accuracy: 0.8000
# Epoch 98/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0862 - accuracy: 0.9394 - val_loss: 0.3702 - val_accuracy: 0.6667
# Epoch 99/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0589 - accuracy: 0.9848 - val_loss: 0.3419 - val_accuracy: 0.8000
# Epoch 100/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0680 - accuracy: 0.9848 - val_loss: 0.2612 - val_accuracy: 0.7333

# %%
import matplotlib.pyplot as plt
# plotting accuracy and validation accuracy
accuracy = fitted_model.history['accuracy']
val_accuracy = fitted_model.history['val_accuracy']
plt.plot(range(len(accuracy)), accuracy, 'b-', label = 'accuracy')
plt.plot(range(len(val_accuracy)), val_accuracy, 'r-', label = 'val_accuracy')
plt.legend()

# %%
import glob
filefemale = glob.glob("./test/female/*.*")
filemale = glob.glob("./test/male/*.*")

# %%
from tensorflow.keras.preprocessing import image
# testing the model
plabel = []
for filename in filefemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==0)/len(plabel)
# Out:
# 1.0

# %%
plabel = []
for filename in filemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==1)/len(plabel)
# Out:
# 1.0
